# %% [markdown]
# # 0.4 The Convection and Radiation Rate Equations

# %% [markdown]
# One rate equation down, two to go!  Convection is a close relative of conduction, but radiation is a totally different fish: its mechanism is qualitatively different from conduction and convection.  But let's jump right in!

# %%
# @title ## Video: The Convection Rate Equation {display-mode: "form"}
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = '9iB9Bz37N5s'
display_video(video_id, W=600, H=450)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# <br><br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
# Importing support code
# @title
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name

#@title #======================================= { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Multiple Answer Question* <br><br>Enter the all the correct letters, with a space in between each, and run the cell to check your answer.  <br><br>
home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multAns('0_1_Embedded_Qs', home,7)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_multAns(data,a)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# How can we determine the coefficient 'h' for a given physical system? Submit all that are true
#
# A) Start with mathematical principles and determine what it should be
# B) Look at other situations with known 'h' values and estimate a value
# C) Set up a computational model similar to the physical situation and estimate a value
# D) Apply the convection rate equation to the system
# E) Do an experiment in controlled conditions to estimate a value

# %%
#@title #======================================= { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Multiple Answer Question* <br><br>Enter the all the correct letters, with a space in between each, and run the cell to check your answer.  <br><br>
home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multAns('0_1_Embedded_Qs', home,8)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_multAns(data,a)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# h' is a modeled coefficient: it attempts to capture a complex physical situation with a single value.  What factors are 'abstracted out' in 'h'?  In other words, what physical factors determine its value?  Submit all that are true.
#
# A) The velocity of the flow
# B) The temperature difference between the fluid and surface
# C) The area of the surface
# D) The type of fluid
# E) The shape of the surface
# F) The roughness of the surface

# %%
#@title #=======================================  { run: "auto", form-width: "30%", display-mode: "form" }
#@markdown ###### *Multiple Choice (Choose the correct answer)* { run: "auto", form-width: "50%", display-mode: "form" }


home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multC('0_1_Embedded_Qs',home,9)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# How does convection 'enhance' conduction?
#
# A) It increases the thermal conductivity of the fluid
# B) It increases the thermal conductivity of the solid
# C) It artificially increases the area of contact
# D) It removes fluid next to the solid that is approaching equilibrium with the solid

# %%
#@title #======================================= { run: "auto", form-width: "30%", display-mode: "form" }
#@markdown ###### *Multiple Choice (Choose the correct answer)* { run: "auto", form-width: "50%", display-mode: "form" }


home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multC('0_1_Embedded_Qs',home,10)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# When you go swimming in cold water, you "get used to it" after a while, and it doesn't feel as cold.  Why do you think that is?
#
# A) The effects of convection fade with time
# B) Your skin has cooled down, and so the temperature difference between the water and skin is smaller
# C) The water has heated up, and so the temperature difference between the water and skin is smaller
# D) Once you jump in and are standing still, there is less convection

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>

# %%
# @title ## Video: The Radiation Rate Equation {display-mode: "form"}
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = 'EQbCAiIP5nE'
display_video(video_id, W=600, H=450)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# <br><br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
#@title { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Multiple Answer Question* <br><br>Enter the all the correct letters, with a space in between each, and run the cell to check your answer.  <br><br>
home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multAns('0_1_Embedded_Qs', home,11)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_multAns(data,a)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Which of the three modes of heat transfer can heat a satellite moving through outer space?  Submit all that are true.
#
# A) Conduction
# B) Convection
# C) Radiation

# %%
#@title #======================================= { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Multiple Answer Question* <br><br>Enter the all the correct letters, with a space in between each, and run the cell to check your answer.  <br><br>
home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multAns('0_1_Embedded_Qs', home,12)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_multAns(data,a)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Radiation depends *heavily* on temperature (to the fourth power).  What can we conclude from this?  Submit all that are true.
#
# A) Radiation usually transfers more heat than other  modes
# B) It requires a lot of molecular kinetic energy to produce EM waves that carry a significant energy
# C) Radiation becomes more and more important the higher the absolute temperatures are involved in a system
# D) Cold materials absorb radiation but do not usually emit radiation

# %% [markdown]
# # ===========================================

# %%
#@title  { run: "auto", form-width: "30%", display-mode: "form" }
#@markdown ###### *Multiple Choice (Choose the correct answer)* { run: "auto", form-width: "50%", display-mode: "form" }


home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multC('0_1_Embedded_Qs',home,13)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Why does surface color and roughness matter so much for radiation?
#
# A) Radiation from internal molecules tends to get absorbed by other internal molecules in the same material
# B) Internal molecules do not radiate
# C) Molecules near the surface tend to have more kinetic energy, and so radiate more

# %%
#@title #======================================= {form-width: "50%", display-mode: "form" }
#@markdown ##### *Quantitative Question* <br><br>Enter your answer, and run the cell to check your answer.  <br><br>

home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_Quant('0_1_Embedded_Qs',home,14)
answer = None #@param {type:"number"}
check_Quant(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# A company produces ball bearings.  Coming out of the furnace, a ball bearing has a temperature of 800 degrees C; a cooled one has a temperature of 20 degrees C.  How much more energy is the hot ball bearing radiating than the cooler one?  Express your answer as a ratio to 1 (so if the answer is 10:1, enter 10).

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>

# %% [markdown]
# # 0.4 The Convection and Radiation Rate Equations

# %% [markdown]
# The most fundamental equations in heat transfer are the rate equations: one for each of the three modes (conduction, convection, and radiation).  These rate equations are boiled down to the basics: any complications in the material or environment are abstracted out.
#
# <br>
#
# We'll start with conduction rate equation, which is also known as Fourier's Law.

# %%
# @title ## Video: Fourier's Law {display-mode: "form"}
# @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = 'Vm8J4b5mja4'
display_video(video_id, W=600, H=450)

# %% [markdown]
# <br><br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
# Importing support code
# @title
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name

#@title #======================================= { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Multiple Answer Question* <br><br>Enter the all the correct letters, with a space in between each, and run the cell to check your answer.  <br><br>
home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multAns('0_1_Embedded_Qs', home,0)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_multAns(data,a)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# If a solid is heated on one side, which of the following would increase the heat transfer through  the solid?  Answer with all that are true.
#
# A) A large thickness
# B) A high temperature difference between the hot and cold side
# C) A high heat transfer coefficient
# D) A large cross-sectional area

# %%
#@title #=======================================  { run: "auto", form-width: "30%", display-mode: "form" }
#@markdown ###### *Multiple Choice (Choose the correct answer)* { run: "auto", form-width: "50%", display-mode: "form" }


home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multC('0_1_Embedded_Qs',home,1)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Considering that conduction works largely through collisions of molecules, what phase of material do you think would have the largest thermal conductivity?
#
# A) Solid
# B) Liquid
# C) Gas

# %%
#@title #======================================= { run: "auto", form-width: "30%", display-mode: "form" }
#@markdown ###### *Multiple Choice (Choose the correct answer)* { run: "auto", form-width: "50%", display-mode: "form" }


home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multC('0_1_Embedded_Qs',home,2)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Two geometrically identical solids that are at a constant temperature throughout are suddenly heated on one side.  One has a higher thermal diffusivity 'alpha' than the other, but both have the same thermal conductivity 'k'.  Which of the following is true?
#
# A) The material with the higher 'alpha' would heat up more slowly
# B) The materials would heat up at the same rate
# C) The material with the higher 'alpha'  would heat up more quickly

# %%
#@title #======================================= { run: "auto", form-width: "30%", display-mode: "form" }
#@markdown ###### *Multiple Choice (Choose the correct answer)* { run: "auto", form-width: "50%", display-mode: "form" }


home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multC('0_1_Embedded_Qs',home,3)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Two geometrically identical solids that are at a constant temperature throughout are suddenly heated on one side.  One has a higher thermal diffusivity 'alpha' than the other, but both have the same thermal conductivity 'k'.  Which of the following is true?
#
# A) Once at steady state, the material with the higher 'alpha' would have a smaller heat flux
# B) Once at steady state, both materials would have the same heat flux
# C) Once at steady state, the material with the higher 'alpha' would have a larger heat flux

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>

# %%
# @title ## Video: Special Cases for Fourier's Law {display-mode: "form"}
# @markdown Run this cell to watch this video, and answer the questions below.
from IPython.display import YouTubeVideo

def display_video(video_id, W=400, H=300, fs=1):
    video = YouTubeVideo(id=video_id, width=W, height=H, fs=fs, rel=0)
    display(video)
    #print(f'Video available at https://youtube.com/watch?v={video.id}')
    return

video_id = 'ROXjMUnqo4I'
display_video(video_id, W=600, H=450)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# <br><br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning Questions </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br>

# %%
#@title { run: "auto", form-width: "30%", display-mode: "form" }
#@markdown ###### *Multiple Choice (Choose the correct answer)* { run: "auto", form-width: "50%", display-mode: "form" }


home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multC('0_1_Embedded_Qs',home,4)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# A uniform material with a uniform cross-sectional area is heated on one side.  Fourier's Law tells us at steady-state, the temperature within the material must:
#
# A) Have a linear temperature field
# B) Have a temperature field whose slope increases as it approaches the hotter side
# C) Have an overall thermal energy level that is increasing linearly
# D) Have a constant temperature field

# %% [markdown]
# # ===========================================

# %% [markdown]
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/0_Images/temp_field.PNG width = 450>
# </center>
#
# <br>

# %%
#@title  { run: "auto", form-width: "30%", display-mode: "form" }
#@markdown ###### *Multiple Choice (Choose the correct answer)* { run: "auto", form-width: "50%", display-mode: "form" }


home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multC('0_1_Embedded_Qs',home,5)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# The plot above shows the temperature field of a material with a constant cross-sectional area that is heated on one side.  Is the flux on the left side of the boxed area (at 'x=0.6') into or out of the boxed area?
#
# A) The flux is into the boxed area (that is thermal energy is moving from left to right)
# B) There is no flux 'x=0.6'
# C) The flux is out of the boxed area (that is thermal energy is moving from right to left)

# %%
#@title #======================================= { run: "auto", form-width: "30%", display-mode: "form" }
#@markdown ###### *Multiple Choice (Choose the correct answer)* { run: "auto", form-width: "50%", display-mode: "form" }


home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/0_Fundamentals/Embedded_Qs_and_Data/'
data = display_multC('0_1_Embedded_Qs',home,6)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# The plot above shows the temperature field of a material with a constant cross-sectional area that is heated on one side.  What is happening to the temperature of the material represented by the box (between 'x=0.6' and 'x=0.8'?
#
# A) It is getting lower with time
# B) It is staying the same
# C) It is getting higher with time

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>

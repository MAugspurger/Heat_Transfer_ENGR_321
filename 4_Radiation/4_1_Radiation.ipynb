# %% [markdown]
# # Radiation
#
# The video for this notebook is still in the works, so you'll need to look at the PDF of the notes in order to answer the questions.  [Here are the notes.](https://drive.google.com/open?id=1zwXF6hFrhEWSAYrgDvXc40k9AeUA9rF5&usp=drive_fs)

# %% [markdown]
# <br><br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---

# %%
import pandas as pd
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name
home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/4_Radiation/Embedded_Qs/'
efile = '4_1_Embedded_Qs'

#@markdown ##### <br> *Multiple Answer Question* <br><br>Enter the all the correct letters, with a space in between each, and run the cell to check your answer.  <br><br>
data = display_multAns(efile, home,0)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_multAns(data,a)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Which of the following are true of radiation?  Submit all that are true
#
# A) Gases don't radiate thermal energy
# B) Only the molecules on the surface of a material radiate thermal energy
# C) Radiation requires no intervening medium to carry its thermal energy
# D) Only molecules that have asymmetrical structures radiate thermal energy

# %% [markdown]
# #=======================================
#
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/4_Radiation/Images/Planck_dist.PNG width = 500>
# </center>

# %%
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,1)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# An blackbody at 2000 K has a peak emission wavelength of approximately 1 micrometer.   Take a moment to look up the EM spectrum: what type of EM wave is this?
#
# A) Ultraviolet
# B) Visible light
# C) Infrared
# D) Microwave

# %% [markdown]
# #=======================================
#
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/4_Radiation/Images/Planck_500.PNG width = 500>
# </center>

# %%
#@title  { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,2)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Look at the blackbody emissions of a 500 K object. If we wanted to understand the total emissive power of the object from this plot, what should we identify?
#
# A) Lambda_max, the wavelength with the maximum spectral emission
# B) The emissive power at the peak of the plot
# C) The derivative of the curve at the peak of the plot
# D) The integral of the curve from 0 to 40 micrometers

# %%
#@title #======================================= { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Multiple Answer Question* <br><br>Enter the all the correct letters, with a space in between each, and run the cell to check your answer.  <br><br>
data = display_multAns(efile, home,3)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_multAns(data,a)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# A blackbody is a perfect emitter (and absorber) of radiation.   What is the emissive power of a blackbody a function of?  In other words, what factors cause a blackbody to have different emissive power?  Submit all that are true.
#
# A) Wavelength
# B) Direction
# C) Temperature
# D) Roughness of surface
# E) Surface material

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,4)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# If the total irradiation G onto a flat plate is 100 W/m2, the absorptivity of the plate is 0.6, and the reflectivity is 0.3, how much radiation is transmitted through the plate?
#
# A) 0 W/m2
# B) 10 W/m2
# C) 30 W/m2
# D) 40 W/m2
# E) 70 W/m2

# %%
#@title #======================================= { form-width: "50%", display-mode: "form" }
#@markdown ##### <br> *Multiple Answer Question* <br><br>Enter the all the correct letters, with a space in between each, and run the cell to check your answer.  <br><br>
data = display_multAns(efile, home,5)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_multAns(data,a)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# In a solar eclipse, the moon completely covers the sun.  What does this imply about the sun and the moon? Submit all that are true.
#
# A) That they have the same cross-sectional area.
# B) That the solid angle subtended by the moon from the perspective of the sun is the same as the projected area of the sun as seen from the moon.
# C) That they have the same angle at the surface of the earth.
# D) That the ratio of their cross-sectional area to the sqare of their distance from the earth's surface is the same

# %% [markdown]
# #=======================================
#
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/4_Radiation/Images/solid_angle.PNG width = 500>
# </center>

# %%
#@title { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,6)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# In the image above, what happens to the solid angle subtended by the receiving surface if theta_rec gets smaller?
#
# A) The solid angle gets smaller
# B) The solid angle stays the same
# C) The solid angle gets larger

# %%
#@title #======================================= { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,7)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# In the image above, why does the heat transfer between the two surfaces get smaller when theta_emit gets smaller?
#
# A) When theta_emit is smaller, the projected area of the emitting surface becomes smaller
# B) When theta_emit is smaller, the projected area of the emitting surface becomes larger
# C) When theta_emit is smaller, the solid angle of the emitting surface becomes smaller
# D) When theta_emit is smaller, the solid angle of the emitting surface becomes larger

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>

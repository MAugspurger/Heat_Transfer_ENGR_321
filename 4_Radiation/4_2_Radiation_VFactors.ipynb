# %% [markdown]
# # Radiation View Factors
#
# The video for this notebook is still in the works, so you'll need to look at the PDF of the notes in order to answer the questions.  [Here are the notes.](https://drive.google.com/open?id=1djqsqhBidxyVSzH0_kVcrGitvHVD7ZZN&usp=drive_fs)

# %% [markdown]
# <br><br><br>
#
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷<font size = 5> Active Learning </font> 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---

# %%
import pandas as pd
from urllib.request import urlretrieve

location = 'https://github.com/MAugspurger/ModSimPy_MAugs/raw/main/'
folder = 'Support_files/'
name = 'Embedded_Qs.ipynb'
local, _ = urlretrieve(location + folder + name, name)
# %run /content/$name
home = 'https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/4_Radiation/Embedded_Qs/'
efile = '4_2_Embedded_Qs'

#@markdown ##### <br> *Multiple Answer Question* <br><br>Enter the all the correct letters, with a space in between each, and run the cell to check your answer.  <br><br>
data = display_multAns(efile, home,0)
answer = "" #@param {type:"string"}
a = answer.split(sep=" ")
check_multAns(data,a)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Consider a general view factor problem that involves two flat plates.   Which of the following lead to a larger view factor F_ij ("the fraction of radiative heat leaving plate i that would hit plate j")?  Submit all that are true
#
# A) Increasing the distance between the plates
# B) Increasing the size of plate i
# C) Increasing the size of plate j
# D) Changing theta_i to be closer to 0
# E) Changing theta_j to be closer to 0

# %% [markdown]
# #=======================================
#
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/4_Radiation/Images/equilateral.PNG width = 300>
# </center>

# %%
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,1)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Consider the equilateral triangle above.  Which of the three view factor relations from the notes suggests that F_ij + F_ik = 1?
#
# A) Summation
# B) Additive
# C) Symmetry

# %% [markdown]
# #=======================================
#
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/4_Radiation/Images/view_fact_ex.PNG width = 400>
# </center>

# %%
#@title  { run: "auto", form-width: "50%", display-mode: "form" }
#@markdown #####*Multiple Choice*:  <br><br> Choose the correct letter.  <br><br>
data = display_multC(efile,home,2)
answer = "" # @param ["", "A", "B", "C", "D", "E"]
check_multC(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Look at the example shown.  Is the view factor from A to B larger/ smaller/ the same as the view factor from B to A?
#
# A) F_AB is larger
# B) F_BA is larger
# C) F_AB = F_BA

# %% [markdown]
# #=======================================
#
# <br>
#
# <center>
# <img src = https://github.com/MAugspurger/Heat_Transfer_ENGR_321/raw/main/4_Radiation/Images/view_factor.PNG width = 500>
# </center>

# %%
#@title {form-width: "50%", display-mode: "form" }
#@markdown ##### *Quantitative Question* <br><br>Enter your answer, and run the cell to check your answer.  <br><br>
data = display_Quant(efile,home,3)
answer = None #@param {type:"number"}
check_Quant(data,answer)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Use the plot of calculated view factors to determine approximate value of F_AB.  What is that value?

# %% [markdown]
# ---
# 🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷🔷
#
# ---
#
# <br><br><br>
